# %% [markdown]
# By: Mohd Tabish Husain
#
# Data Science and Business Analyst Internship at The Sparks Foundation (September 2022)
#
# Task 3 - Exploratory Data Analysis - Retail

# %% [markdown]
# # Step 1 - Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Step 2 - Importing Dataset and Printing the data

# %%
#Loading Dataset
df=pd.read_csv('~/SampleSuperstore.csv')

# %%
#Printing first 5 rows 
df.head(5)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
#Printing last 5 rows
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# # Step 3 - Problem Statement

# %% [markdown]
# We have to -
#
# 1. Check Which City has highest sale and which city has lowest sale.
#
#
# 2. Check Which City has highest profit and which city has lowest profit.
#
#
# 3. Check Which State has highest sale and which State has lowest sale.
#
#
# 4. Check Which State has highest profit and which State has lowest profit.
#
#
# 5. Check Which Region has highest sale and which Region has lowest sale.
#
#
# 6. Check Which Region has highest profit and which Region has lowest profit.
#
#
# 7. Check Which Category has highest sale and which Category has lowest sale.
#
#
#
# 8. Check Which Category has highest profit and which Category has lowest profit.
#
#
#
# 9. Check Which Sub-Category has highest sale and which Sub-Category has lowest sale.
#
#
# 10. Check Which Sub-Category has highest profit and which Sub-Category has lowest profit.
#
#
# 11. Check Which Ship Mode has highest sale and which Ship Mode has lowest sale.
#
#
# 12. Check Which Ship Mode has highest profit and which Ship Mode has lowest profit.
#
#
# 13. Check Which Segment has highest sale and which Segment has lowest sale.
#
#
# 14. Check Which Segment has highest profit and which Segment has lowest profit.
#
#
# Draw a final conclusion from this data

# %% [markdown]
# # Step 3 - Exploring the data

# %%
#Calculating mean, standard deviation etc.
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#Checking duplicate values
df.duplicated().sum()
# Out:
# 17

# %%
#Dropping the duplicates
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#Checking Correlation
corr=df.corr()
corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
#Visualising the Correlation
sns.heatmap(corr,cmap=['red','yellow', 'blue'], annot= True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking Frequency in each Categorical column

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df['City'].value_counts()
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64

# %%
df['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
no_loss=df['Profit']>0.0

# %%
no_profit=df['Profit']<0.0

# %% [markdown]
# # Cities with highest and lowest sales and profits

# %%
#Sales
df.groupby("City")["Quantity"].sum().sort_values(ascending=False)
# Out:
# City
# New York City        3417
# Los Angeles          2879
# Philadelphia         1981
# San Francisco        1935
# Seattle              1590
# Houston              1466
# Chicago              1132
# Columbus              836
# San Diego             670
# Springfield           649
# Dallas                555
# Detroit               441
# Jacksonville          429
# Newark                362
# Richmond              336
# Jackson               318
# Columbia              316
# Arlington             259
# Aurora                258
# Long Beach            256
# San Antonio           247
# Charlotte             243
# Phoenix               224
# Louisville            221
# Miami                 215
# Lakewood              204
# Milwaukee             201
# Henderson             198
# Fairfield             185
# Baltimore             184
# Lancaster             171
# Rochester             170
# Fayetteville          168
# Lawrence              166
# Denver                164
# ...

# %% [markdown]
# New York City is the city with most sales

# %% [markdown]
# Elyria, Iowa City, Jupiter, Lindenhurst, Littleton and Port Orange are the cities with least sales

# %%
# Profit
df.groupby("City")["Profit"].sum().sort_values(ascending=False)
# Out:
# City
# New York City        62036.9837
# Los Angeles          30440.7579
# Seattle              29156.0967
# San Francisco        17507.3854
# Detroit              13181.7908
# Lafayette            10018.3876
# Jackson               7581.6828
# Atlanta               6993.6629
# Minneapolis           6824.5846
# San Diego             6377.1960
# Springfield           6200.6974
# Columbus              5897.1013
# Newark                5793.7588
# Columbia              5606.1167
# Richmond              5567.2486
# Providence            5505.6569
# Henderson             4911.8609
# Arlington             4169.6969
# Lakewood              3234.0278
# Milwaukee             2793.0851
# Yonkers               2767.7557
# Indianapolis          2741.6538
# Roswell               2427.4353
# Lawrence              2382.1465
# Midland               2293.6828
# North Las Vegas       2247.6899
# Mobile                2175.8292
# Florence              2168.9661
# Long Beach            2108.9306
# ...

# %% [markdown]
# New York City is the most profitable city
#
# Philadelphia is the city with highest loss

# %%
# Profit without Loss
Cities_with_no_loss=df[no_loss].groupby(['City']).sum().sort_values(by='Profit',ascending=False)
Cities_with_no_loss
# Out:
#                    Postal Code        Sales  Quantity  Discount      Profit
# City
# New York City          8697921  234654.7290      3257     39.20  66003.0063
# Los Angeles           63471667  160363.6060      2723     47.60  31611.0879
# Seattle               39831426  113956.7900      1516     24.40  29541.2676
# San Francisco         45363161   99342.6380      1839     28.85  18849.1535
# Detroit                5545741   42446.9440       441      0.80  13181.7908
# Lafayette              1866569   25030.2600       101      0.00  10018.3876
# Springfield            7131527   37031.2140       520      8.80   9368.9202
# Newark                 2129870   23921.5220       313      4.40   8970.5590
# Columbus               6757311   29384.4460       636     14.20   7914.9880
# Jackson                3509254   23819.3340       310      1.90   7854.5808
# Atlanta                1182402   17197.8400       156      0.00   6993.6629
# ...

# %%
# Loss without profit
Cities_with_no_profit=df[no_profit].groupby(['City']).sum().sort_values(by='Profit',ascending=False)
Cities_with_no_profit
# Out:
#                   Postal Code       Sales  Quantity  Discount      Profit
# City
# Coppell                 75019     16.7840         1      0.20     -0.2098
# Homestead               33030      2.9440         1      0.20     -0.6624
# Elyria                  44035      1.8240         1      0.70     -1.3984
# Pensacola               32503      2.2140         3      0.70     -1.4760
# Loveland               161076      4.2120         5      0.90     -1.5948
# North Miami             33161      7.6320         3      0.20     -1.8126
# Ormond Beach            32174      2.8080         3      0.70     -1.9656
# Port Saint Lucie        34952      2.6940         2      0.70     -2.2450
# Thomasville             27360      3.2040         2      0.70     -2.4564
# Des Moines              98198    215.9760         3      0.20     -2.6997
# Sunnyvale               94086    215.9760         3      0.20     -2.6997
# Grove City              43123      3.6480         2      0.70     -2.7968
# ...

# %% [markdown]
# # States with Highest and Lowest Sales and Profits

# %%
#Sales
df.groupby("State")["Quantity"].sum().nlargest(50)
# Out:
# State
# California              7667
# New York                4224
# Texas                   3724
# Pennsylvania            2153
# Washington              1883
# Illinois                1845
# Ohio                    1759
# Florida                 1379
# North Carolina           983
# Michigan                 946
# Virginia                 893
# Arizona                  862
# Georgia                  705
# Colorado                 693
# Tennessee                681
# Indiana                  578
# Kentucky                 523
# Oregon                   499
# Massachusetts            491
# Wisconsin                463
# New Jersey               454
# Maryland                 420
# Delaware                 367
# Minnesota                331
# Connecticut              281
# Alabama                  256
# Missouri                 252
# Oklahoma                 247
# Arkansas                 240
# Mississippi              221
# Utah                     219
# Rhode Island             199
# ...

# %% [markdown]
# California has highest sales and Wycoming has lowest sales

# %%
#Profit
df.groupby("State")["Profit"].sum().nlargest(50)
# Out:
# State
# California              76381.3871
# New York                74038.5486
# Washington              33402.6517
# Michigan                24463.1876
# Virginia                18597.9504
# Indiana                 18382.9363
# Georgia                 16250.0433
# Kentucky                11199.6966
# Minnesota               10823.1874
# Delaware                 9977.3748
# New Jersey               9772.9138
# Wisconsin                8401.8004
# Rhode Island             7285.6293
# Maryland                 7031.1788
# Massachusetts            6785.5016
# Missouri                 6436.2105
# Alabama                  5786.8253
# Oklahoma                 4853.9560
# Arkansas                 4008.6871
# Connecticut              3511.4918
# Nevada                   3316.7659
# Mississippi              3172.9762
# Utah                     2546.5335
# Vermont                  2244.9783
# Louisiana                2196.1023
# Nebraska                 2037.0942
# ...

# %% [markdown]
# California is most profitable whereas Texas has most loss

# %%
# Profit without Loss
States_with_no_loss=df[no_loss].groupby(['State']).sum().sort_values(by='Profit',ascending=False)
States_with_no_loss
# Out:
#                       Postal Code        Sales  Quantity  Discount      Profit
# State
# California              173606735  415409.2655      7255    124.05  80151.0522
# New York                 11275905  282163.2910      4036     47.80  79069.6864
# Washington               47405157  132841.3420      1806     28.80  33790.5223
# Michigan                 12307916   75767.8040       943      1.80  24463.1876
# Virginia                  5056926   69868.9700       870      0.00  18597.9504
# Indiana                   6943697   53549.4200       575      0.00  18382.9363
# Georgia                   5685480   49095.8400       705      0.00  16250.0433
# Kentucky                  5682916   35762.9100       517      0.00  11199.6966
# Texas                    37893544   65134.0080      1842     99.70  11083.8312
# Minnesota                 4876817   29361.3400       328      0.00  10823.1874
# Delaware                  1856894   26940.7900       360      0.00  10063.2711
# ...

# %%
# Loss without profit
States_with_no_profit=df[no_profit].groupby(['State']).sum().sort_values(by='Profit',ascending=False)
States_with_no_profit
# Out:
#                 Postal Code        Sales  Quantity  Discount      Profit
# State
# New Mexico            87105      23.9760         3      0.20     -5.6943
# Connecticut           12834     252.3570         2      0.60    -19.6146
# New Jersey            15415     418.2920         4      0.60    -51.2906
# Maryland              41950     789.8030         5      0.60    -71.1170
# West Virginia         26003     673.3440         3      0.30    -76.9536
# Delaware              39610     510.2790         7      0.60    -85.8963
# New Hampshire          3820    1053.1640         4      0.30   -105.3164
# Nevada                89031     674.3520         3      0.20   -109.5822
# Rhode Island          11668    1758.2460        15      1.20   -230.1678
# Washington          1667904    4038.4960        56      3.40   -387.8706
# Massachusetts          9796    3275.3210        17      1.50   -566.2617
# Oregon              4186090    6645.7660       187     19.60  -2890.4764
# ...

# %% [markdown]
# # Region with Highest and Lowest Sales and Profits

# %%
# Sales
df.groupby("Region")["Quantity"].sum()
# Out:
# Region
# Central     8780
# East       10618
# South       6209
# West       12266
# Name: Quantity, dtype: int64

# %%
df.groupby("Region")["Quantity"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %% [markdown]
# West Region has most sales and South Region has least sales

# %%
df.groupby("Region")["Profit"].sum()
# Out:
# Region
# Central     39706.3625
# East        91522.7800
# South       46749.4303
# West       108418.4489
# Name: Profit, dtype: float64

# %%
df.groupby("Region")["Profit"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %% [markdown]
# West Region is most profitable and central region is least profitable

# %%
# Profit without Loss
Regions_with_no_loss=df[no_loss].groupby(['Region'])['Profit'].sum().sort_values(ascending=False)
Regions_with_no_loss
# Out:
# Region
# East       141113.3875
# West       131139.4098
# Central     96021.2475
# South       74254.2626
# Name: Profit, dtype: float64

# %%
Regions_with_no_loss.plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
# Loss without profit
Regions_with_no_profit=df[no_profit].groupby(['Region'])['Profit'].sum().sort_values(ascending=False)
Regions_with_no_profit
# Out:
# Region
# West      -22720.9609
# South     -27504.8323
# East      -49590.6075
# Central   -56314.8850
# Name: Profit, dtype: float64

# %%
Regions_with_no_profit.plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %% [markdown]
# # Category with highest and lowest sales and profit

# %%
# Sales
df.groupby("Category")["Quantity"].sum()
# Out:
# Category
# Furniture           8028
# Office Supplies    22906
# Technology          6939
# Name: Quantity, dtype: int64

# %%
df.groupby("Category")["Quantity"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# Office supply has highest sales and technology has lowest sales

# %%
# Profit
df.groupby("Category")["Profit"].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64

# %%
df.groupby("Category")["Profit"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# Technology is the most profitable and furniture is least profitable

# %%
# Profit without Loss
Category_with_no_loss=df[no_loss].groupby(['Category'])['Profit'].sum().sort_values(ascending=False)
Category_with_no_loss
# Out:
# Category
# Technology         184034.8663
# Office Supplies    179106.0593
# Furniture           79387.3818
# Name: Profit, dtype: float64

# %%
Category_with_no_loss.plot.bar()
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
# Loss without profit
Category_with_no_profit=df[no_profit].groupby(['Category'])['Profit'].sum().sort_values(ascending=False)
Category_with_no_profit
# Out:
# Category
# Technology        -38579.9182
# Office Supplies   -56615.2585
# Furniture         -60936.1090
# Name: Profit, dtype: float64

# %%
Category_with_no_profit.plot.bar()
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# # Sub - Category with Highest and Lowest Sales and Profit

# %%
# Sales
df.groupby("Sub-Category")["Quantity"].sum()
# Out:
# Sub-Category
# Accessories    2976
# Appliances     1729
# Art            3000
# Binders        5974
# Bookcases       868
# Chairs         2356
# Copiers         234
# Envelopes       906
# Fasteners       914
# Furnishings    3563
# Labels         1400
# Machines        440
# Paper          5178
# Phones         3289
# Storage        3158
# Supplies        647
# Tables         1241
# Name: Quantity, dtype: int64

# %%
df.groupby("Sub-Category")["Quantity"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# Binders has highest sales and clippers has lowest sales

# %%
# Profit
df.groupby("Sub-Category")["Profit"].sum()
# Out:
# Sub-Category
# Accessories    41936.6357
# Appliances     18138.0054
# Art             6527.7870
# Binders        30221.7633
# Bookcases      -3472.5560
# Chairs         26590.1663
# Copiers        55617.8249
# Envelopes       6964.1767
# Fasteners        949.5182
# Furnishings    13059.1436
# Labels          5546.2540
# Machines        3384.7569
# Paper          34053.5693
# Phones         44515.7306
# Storage        21278.8264
# Supplies       -1189.0995
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
df.groupby("Sub-Category")["Profit"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# Copiers is the most profitable and tables has most loss

# %%
# Profit without Loss
Sub_Category_with_no_loss=df[no_loss].groupby(['Sub-Category'])['Profit'].sum().sort_values(ascending=False)
Sub_Category_with_no_loss
# Out:
# Sub-Category
# Binders        68732.2597
# Copiers        55617.8249
# Phones         52046.3541
# Accessories    42867.2622
# Chairs         36471.0076
# Paper          34053.5693
# Machines       33503.4251
# Storage        27705.1302
# Appliances     26767.6466
# Furnishings    19550.0570
# Tables         14686.6672
# Bookcases       8679.6500
# Envelopes       6964.1767
# Art             6527.7870
# Labels          5546.2540
# Supplies        1826.5224
# Fasteners        982.7134
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10,5))
Sub_Category_with_no_loss.plot.bar()
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %%
# Loss without profit
Sub_Category_with_no_profit=df[no_profit].groupby(['Sub-Category'])['Profit'].sum().sort_values(ascending=False)
Sub_Category_with_no_profit
# Out:
# Sub-Category
# Fasteners        -33.1952
# Accessories     -930.6265
# Supplies       -3015.6219
# Storage        -6426.3038
# Furnishings    -6490.9134
# Phones         -7530.6235
# Appliances     -8629.6412
# Chairs         -9880.8413
# Bookcases     -12152.2060
# Machines      -30118.6682
# Tables        -32412.1483
# Binders       -38510.4964
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10,5))
Sub_Category_with_no_profit.plot.bar()
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# # Ship Mode with Highest and Lowest Sales and Profit

# %%
#Sales
df.groupby('Ship Mode')['Quantity'].sum()
# Out:
# Ship Mode
# First Class        5693
# Same Day           1960
# Second Class       7423
# Standard Class    22797
# Name: Quantity, dtype: int64

# %%
df.groupby('Ship Mode')['Quantity'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Ship Mode'>

# %% [markdown]
# Standard Class ship mode has highest sales whereas Same Day ship mode has lowest sales

# %%
# Profit
df.groupby('Ship Mode')['Profit'].sum()
# Out:
# Ship Mode
# First Class        48969.8399
# Same Day           15891.7589
# Second Class       57446.6354
# Standard Class    164088.7875
# Name: Profit, dtype: float64

# %%
df.groupby('Ship Mode')['Profit'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Ship Mode'>

# %% [markdown]
# Standard Class ship mode is the most profitable whereas Same Day ship mode is least profitable

# %%
# Profit without loss
Ship_Mode_with_no_loss=df[no_loss].groupby(['Ship Mode'])['Profit'].sum().sort_values(ascending=False)
Ship_Mode_with_no_loss
# Out:
# Ship Mode
# Standard Class    264437.3240
# Second Class       81671.0083
# First Class        71630.1108
# Same Day           24789.8643
# Name: Profit, dtype: float64

# %%
Ship_Mode_with_no_loss.plot.bar()
# Out:
# <AxesSubplot:xlabel='Ship Mode'>

# %%
# Loss without profit
Ship_Mode_with_no_profit=df[no_profit].groupby(['Ship Mode'])['Profit'].sum().sort_values(ascending=False)
Ship_Mode_with_no_profit
# Out:
# Ship Mode
# Same Day           -8898.1054
# First Class       -22660.2709
# Second Class      -24224.3729
# Standard Class   -100348.5365
# Name: Profit, dtype: float64

# %%
Ship_Mode_with_no_profit.plot.bar()
# Out:
# <AxesSubplot:xlabel='Ship Mode'>

# %% [markdown]
# # Segment with Highest and Lowest Sales and Profit

# %%
# Sales
df.groupby('Segment')['Sales'].sum()
# Out:
# Segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: Sales, dtype: float64

# %%
df.groupby('Segment')['Sales'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Segment'>

# %% [markdown]
# Consumer segment has most sales whereas Home Office segment has least sales

# %%
df.groupby('Segment')['Profit'].sum()
# Out:
# Segment
# Consumer       134119.2092
# Corporate       91979.1340
# Home Office     60298.6785
# Name: Profit, dtype: float64

# %%
df.groupby('Segment')['Profit'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Segment'>

# %% [markdown]
# Consumer segment has most profit whereas Home Office segment has least profit

# %%
# Profit without loss
Segment_with_no_loss=df[no_loss].groupby(['Segment'])['Profit'].sum().sort_values(ascending=False)
Segment_with_no_loss
# Out:
# Segment
# Consumer       219064.9204
# Corporate      136766.3416
# Home Office     86697.0454
# Name: Profit, dtype: float64

# %%
Segment_with_no_loss.plot.bar()
# Out:
# <AxesSubplot:xlabel='Segment'>

# %%
# Loss without Profit
Segment_with_no_profit=df[no_profit].groupby(['Segment'])['Profit'].sum().sort_values(ascending=False)
Segment_with_no_profit
# Out:
# Segment
# Home Office   -26398.3669
# Corporate     -44787.2076
# Consumer      -84945.7112
# Name: Profit, dtype: float64

# %%
Segment_with_no_profit.plot.bar()
# Out:
# <AxesSubplot:xlabel='Segment'>

# %% [markdown]
# # Profit without loss of Region by Ship Mode, Segment, Category, Sub - Category

# %%
df[no_loss].groupby(['Region','Ship Mode','Segment','Category','Sub-Category'])['Profit'].sum().sort_values(ascending=False)
# Out:
# Region   Ship Mode       Segment      Category         Sub-Category
# Central  Standard Class  Corporate    Technology       Copiers         12516.9127
#                          Consumer     Office Supplies  Binders         10869.5932
# East     Standard Class  Consumer     Technology       Copiers          7760.9478
#                                                        Machines         7211.4103
#                                       Office Supplies  Binders          7030.3879
# West     First Class     Consumer     Technology       Copiers          6779.9788
#          Standard Class  Consumer     Office Supplies  Binders          5924.0253
# South    Standard Class  Consumer     Office Supplies  Binders          5289.5709
# West     Standard Class  Consumer     Technology       Accessories      4981.3306
# East     Standard Class  Consumer     Technology       Phones           4878.9245
#                          Home Office  Technology       Machines         4802.8294
# ...

# %% [markdown]
# # Loss without profit of Region by Ship Mode, Segment, Category, Sub - Category

# %%
df[no_profit].groupby(['Region','Ship Mode','Segment','Category','Sub-Category'])['Profit'].sum().sort_values(ascending=False)
# Out:
# Region   Ship Mode       Segment      Category         Sub-Category
# West     Standard Class  Home Office  Furniture        Furnishings       -0.3398
# Central  Second Class    Consumer     Office Supplies  Supplies          -0.3488
#                          Home Office  Technology       Accessories       -0.6265
# East     Standard Class  Home Office  Office Supplies  Supplies          -0.6976
#          First Class     Home Office  Office Supplies  Fasteners         -0.7128
# West     Second Class    Corporate    Office Supplies  Binders           -0.9900
# South    Standard Class  Home Office  Office Supplies  Supplies          -1.0410
# Central  Second Class    Corporate    Office Supplies  Fasteners         -1.3608
# West     Second Class    Corporate    Technology       Accessories       -1.4590
# Central  First Class     Corporate    Technology       Accessories       -1.4994
# West     Standard Class  Consumer     Office Supplies  Fasteners         -1.5534
# ...

# %% [markdown]
# # Profit without loss of State by Ship Mode, Segment, Category, Sub - Category

# %%
df[no_loss].groupby(['State','Ship Mode','Segment','Category','Sub-Category'])['Profit'].sum().sort_values(ascending=False)
# Out:
# State                 Ship Mode       Segment      Category         Sub-Category
# Indiana               Standard Class  Corporate    Technology       Copiers         8399.9760
# Washington            First Class     Consumer     Technology       Copiers         6719.9808
# New York              Standard Class  Consumer     Technology       Machines        6097.0055
# Michigan              Standard Class  Consumer     Office Supplies  Binders         5921.5224
# Delaware              Standard Class  Consumer     Technology       Copiers         5039.9856
# New York              Standard Class  Home Office  Technology       Machines        4802.8294
# Minnesota             Standard Class  Consumer     Office Supplies  Binders         4720.7865
# New York              Standard Class  Consumer     Office Supplies  Binders         4450.3685
#                       First Class     Home Office  Technology       Copiers         3919.9888
# ...

# %% [markdown]
# # Loss without profit of State by Ship Mode, Segment, Category, Sub - Category

# %%
df[no_profit].groupby(['State','Ship Mode','Segment','Category','Sub-Category'])['Profit'].sum().sort_values(ascending=False)
# Out:
# State           Ship Mode       Segment      Category         Sub-Category
# Oregon          Standard Class  Home Office  Furniture        Furnishings       -0.3398
# Texas           Second Class    Consumer     Office Supplies  Supplies          -0.3488
# Colorado        Standard Class  Consumer     Office Supplies  Fasteners         -0.6048
# Illinois        Second Class    Home Office  Technology       Accessories       -0.6265
# Florida         Standard Class  Consumer     Office Supplies  Supplies          -0.6624
# Pennsylvania    Standard Class  Home Office  Office Supplies  Supplies          -0.6976
#                 First Class     Home Office  Office Supplies  Fasteners         -0.7128
# Florida         First Class     Consumer     Technology       Accessories       -0.7295
# North Carolina  Standard Class  Home Office  Office Supplies  Storage           -0.7748
# Tennessee       Same Day        Consumer     Office Supplies  Storage           -0.8392
# ...

# %% [markdown]
# # Profit without loss of City by Ship Mode, Segment, Category, Sub - Category

# %%
df[no_loss].groupby(['City','Ship Mode','Segment','Category','Sub-Category'])['Profit'].sum().sort_values(ascending=False)
# Out:
# City               Ship Mode       Segment      Category         Sub-Category
# Lafayette          Standard Class  Corporate    Technology       Copiers         8399.9760
# Seattle            First Class     Consumer     Technology       Copiers         6719.9808
# Detroit            Standard Class  Consumer     Office Supplies  Binders         5736.2153
# Newark             Standard Class  Consumer     Technology       Copiers         5039.9856
# New York City      Standard Class  Home Office  Technology       Machines        4778.7070
# Minneapolis        Standard Class  Consumer     Office Supplies  Binders         4664.7055
# New York City      First Class     Home Office  Technology       Copiers         3919.9888
#                    Standard Class  Consumer     Technology       Machines        3399.9727
# Atlanta            Standard Class  Consumer     Office Supplies  Binders         3178.8372
# ...

# %% [markdown]
# # Loss without profit of City by Ship Mode, Segment, Category, Sub - Category

# %%
df[no_profit].groupby(['City','Ship Mode','Segment','Category','Sub-Category'])['Profit'].sum().sort_values(ascending=False)
# Out:
# City              Ship Mode       Segment      Category         Sub-Category
# Tempe             First Class     Corporate    Technology       Accessories       -0.0895
# Coppell           Standard Class  Consumer     Office Supplies  Storage           -0.2098
# Allen             First Class     Consumer     Technology       Accessories       -0.2685
# Tigard            Standard Class  Home Office  Furniture        Furnishings       -0.3398
# Brownsville       Second Class    Consumer     Office Supplies  Supplies          -0.3488
# Dallas            Standard Class  Home Office  Technology       Accessories       -0.5598
# Houston           Standard Class  Consumer     Technology       Accessories       -0.6008
# Loveland          Standard Class  Consumer     Office Supplies  Fasteners         -0.6048
# Aurora            Second Class    Home Office  Technology       Accessories       -0.6265
# Dallas            Standard Class  Consumer     Technology       Accessories       -0.6265
# ...

# %% [markdown]
# Now we have all the necessary sorted data and we can see which city, state, region has profit and losses
#
# We have to look for reason why these losses hapenning

# %% [markdown]
# # Reason Behind Losses

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df,x='Profit',y='Discount')
plt.title('RelationShip between Profit and Discount')
plt.show()
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Discount'>
# Text(0.5, 1.0, 'RelationShip between Profit and Discount')

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df,x='Profit',y='Ship Mode')
plt.title('RelationShip between Profit and Ship Mode')
plt.show()
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Ship Mode'>
# Text(0.5, 1.0, 'RelationShip between Profit and Discount')

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df,x='Profit',y='Segment')
plt.title('RelationShip between Profit and Segment')
plt.show()
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Segment'>
# Text(0.5, 1.0, 'RelationShip between Profit and Segment')

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df,x='Profit',y='Category')
plt.title('RelationShip between Profit and Category')
plt.show()
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Category'>
# Text(0.5, 1.0, 'RelationShip between Profit and Category')

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df,x='Profit',y='Sub-Category')
plt.title('RelationShip between Profit and Sub-Category')
plt.show()
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Sub-Category'>
# Text(0.5, 1.0, 'RelationShip between Profit and Sub-Category')

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df,x='Profit',y='Region')
plt.title('RelationShip between Profit and Region')
plt.show()
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Region'>
# Text(0.5, 1.0, 'RelationShip between Profit and Region')

# %% [markdown]
# We can see most of the losses are due to discounts on them.

# %% [markdown]
# # Category with highest sales and profit

# %%
plt.figure(figsize=(10,5))
df.groupby('Category')['Profit','Sales'].agg('sum').plot.bar()
plt.ylabel('profit & sales')
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10912\1034231442.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Category')['Profit','Sales'].agg('sum').plot.bar()
# <AxesSubplot:xlabel='Category'>
# Text(0, 0.5, 'profit & sales')
# (array([0, 1, 2]),
#  [Text(0, 0, 'Furniture'),
#   Text(1, 0, 'Office Supplies'),
#   Text(2, 0, 'Technology')])

# %% [markdown]
# Technology has highest sales and profits whereas Furniture has least sales and profit

# %% [markdown]
# # Region with highest sales and profit

# %%
plt.figure(figsize=(50,10))
df.groupby('Region')['Profit','Sales'].agg('sum').plot.bar()
plt.ylabel('profit & sales')
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10912\2121863110.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Region')['Profit','Sales'].agg('sum').plot.bar()
# <AxesSubplot:xlabel='Region'>
# Text(0, 0.5, 'profit & sales')
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Central'),
#   Text(1, 0, 'East'),
#   Text(2, 0, 'South'),
#   Text(3, 0, 'West')])

# %% [markdown]
# West region has highest sales and profit whereas south region has lowest sales and central region has lowest profit

# %% [markdown]
# # Region-Category with highest sales and profits

# %%
plt.figure(figsize=(100,500))
df.groupby(['Region','Category'])['Profit','Sales'].agg('sum').plot.bar()
plt.ylabel('profit & sales')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10912\982981363.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Region','Category'])['Profit','Sales'].agg('sum').plot.bar()
# <AxesSubplot:xlabel='Region,Category'>
# Text(0, 0.5, 'profit & sales')

# %% [markdown]
# # Step 4 - Conclusion

# %% [markdown]
# We can draw the following conclusions
#
# 1. Most of the profit is coming from Technology Category
#
#
# 2. Most of the losses is coming from Furniture Category
#
#
# 3. Discounts are the main reason for losses
#
#
# 4. New York City is the city with highest sales and profit where total profit is 66K approx and loss is 4k approx so pure profit of New York City is 62K.
#
#
# 5. Philadelphia is the city with most loss where total loss is 19.5K approx and profit is 5.75K so pure loss of Philadelphia is 13.75K approx.
#
#
# 6. California is the state with highest profit with pure profit 76K approx.
#
#
# 7. Texas is the state with highest loss with pure loss worth 25.7K approx.
#
#
# 8. West Region is most profitable with a profit of 108K approx and central region is least profitable with a profit of 39.7K approx.
